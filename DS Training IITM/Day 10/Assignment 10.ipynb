# %%
#DAY 10

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r'C:\Users\ratna\OneDrive\Pictures\astronaut.jpg')
arr
# Out:
# array([[[15, 31, 56],
#         [16, 32, 57],
#         [16, 32, 57],
#         ...,
#         [ 7, 36, 32],
#         [12, 32, 30],
#         [11, 38, 31]],
#
#        [[16, 32, 57],
#         [16, 32, 57],
#         [17, 33, 58],
#         ...,
#         [12, 34, 31],
#         [ 7, 36, 31],
#         [11, 36, 32]],
#
#        [[16, 32, 57],
#         [16, 32, 57],
#         [17, 33, 58],
#         ...,
#         [ 9, 36, 31],
#         [10, 37, 32],
#         [ 9, 36, 31]],
#
#        ...,
#
#        [[18,  2,  2],
#         [19,  3,  3],
#         [20,  2,  2],
#         ...,
#         [82, 20, 21],
#         [84, 18, 22],
#         [86, 15, 21]],
#
#        [[18,  2,  3],
#         [19,  3,  3],
#         [19,  3,  3],
#         ...,
#         [82, 20, 21],
#         [83, 19, 20],
#         [84, 18, 20]],
#
#        [[17,  3,  3],
#         [19,  3,  3],
#         [18,  2,  2],
#         ...,
#         [80, 20, 20],
#         [82, 20, 21],
#         [84, 20, 20]]], dtype=uint8)

# %%
astro_arr = arr.copy()

# %%
plt.imshow(astro_arr)

# %%
a = np.random.randint(0,255,(50,50,3))

# %%
plt.imshow(a)

# %%
while True:
    import numpy as np
    import matplotlib.pyplot as plt 
    import time
    a = np.random.randint(0,255,(50,50,3))
    plt.imshow(a)
    display(clear = True)
    time.sleep(2)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       6 plt.imshow(a)
#       7 display(clear = True)
# ----> 8 time.sleep(2)
#       9 plt.show()
#
# KeyboardInterrupt:

# %%
a = np.random.randint(0,255,(3,3,3))
a
# Out:
# array([[[170, 204, 143],
#         [214,  27, 178],
#         [110, 168,  10]],
#
#        [[170, 204,  99],
#         [ 40, 208, 129],
#         [246, 227,  39]],
#
#        [[133, 114, 224],
#         [164, 151, 204],
#         [  5, 125, 182]]])

# %%
plt.imshow(a)

# %%
final_arr = np.split(a,3)
final_arr
# Out:
# [array([[[170, 204, 143],
#          [214,  27, 178],
#          [110, 168,  10]]]),
#  array([[[170, 204,  99],
#          [ 40, 208, 129],
#          [246, 227,  39]]]),
#  array([[[133, 114, 224],
#          [164, 151, 204],
#          [  5, 125, 182]]])]

# %%
len(final_arr)
# Out:
# 3

# %%
plt.imshow(final_arr[1])

# %%
plt.imshow(final_arr[0])

# %%
arr_1 = np.split(a,3,axis = 1)
len(arr_1)
# Out:
# 3

# %%
a
# Out:
# array([[[170, 204, 143],
#         [214,  27, 178],
#         [110, 168,  10]],
#
#        [[170, 204,  99],
#         [ 40, 208, 129],
#         [246, 227,  39]],
#
#        [[133, 114, 224],
#         [164, 151, 204],
#         [  5, 125, 182]]])

# %%
arr_1
# Out:
# [array([[[170, 204, 143]],
#
#         [[170, 204,  99]],
#
#         [[133, 114, 224]]]),
#  array([[[214,  27, 178]],
#
#         [[ 40, 208, 129]],
#
#         [[164, 151, 204]]]),
#  array([[[110, 168,  10]],
#
#         [[246, 227,  39]],
#
#         [[  5, 125, 182]]])]

# %%
np.split(a,3, axis = 2)
# Out:
# [array([[[170],
#          [214],
#          [110]],
#
#         [[170],
#          [ 40],
#          [246]],
#
#         [[133],
#          [164],
#          [  5]]]),
#  array([[[204],
#          [ 27],
#          [168]],
#
#         [[204],
#          [208],
#          [227]],
#
#         [[114],
#          [151],
#          [125]]]),
#  array([[[143],
#          [178],
#          [ 10]],
#
#         [[ 99],
#          [129],
#          [ 39]],
#
#         [[224],
#          [204],
#          [182]]])]

# %%
arr_3_part = np.split(a,3, axis = 2)
arr_3_part
# Out:
# [array([[[170],
#          [214],
#          [110]],
#
#         [[170],
#          [ 40],
#          [246]],
#
#         [[133],
#          [164],
#          [  5]]]),
#  array([[[204],
#          [ 27],
#          [168]],
#
#         [[204],
#          [208],
#          [227]],
#
#         [[114],
#          [151],
#          [125]]]),
#  array([[[143],
#          [178],
#          [ 10]],
#
#         [[ 99],
#          [129],
#          [ 39]],
#
#         [[224],
#          [204],
#          [182]]])]

# %%
plt.imshow(arr_3_part[2])

# %%
len(arr_3_part)
# Out:
# 3

# %%
plt.imshow(np.split(arr,2,axis = 0)[1])

# %%
arr.shape
# Out:
# (1080, 1920, 3)

# %%
1920/3
# Out:
# 640.0

# %%
plt.imshow(arr[:,:640,:])

# %%
plt.imshow(arr[:,640:640*2,:])

# %%
plt.imshow(arr[:,640*2:,:])

# %%
# Where
a = np.random.randint(1,500,(4,4))
a
# Out:
# array([[452,  39, 112, 214],
#        [112, 421, 309, 183],
#        [316, 474, 299, 465],
#        [ 13, 194, 138,  76]])

# %%
np.where(a>200)
# Out:
# (array([0, 0, 1, 1, 2, 2, 2, 2], dtype=int64),
#  array([0, 3, 1, 2, 0, 1, 2, 3], dtype=int64))

# %%
np.where(a>200,'High Sales','Low Sales')
# Out:
# array([['High Sales', 'Low Sales', 'Low Sales', 'High Sales'],
#        ['Low Sales', 'High Sales', 'High Sales', 'Low Sales'],
#        ['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['Low Sales', 'Low Sales', 'Low Sales', 'Low Sales']], dtype='<U10')

# %%
np.where(a>200,'High Sales',a)
# Out:
# array([['High Sales', '39', '112', 'High Sales'],
#        ['112', 'High Sales', 'High Sales', '183'],
#        ['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['13', '194', '138', '76']], dtype='<U11')

# %%
np.clip(a,100,250)
# Out:
# array([[250, 100, 112, 214],
#        [112, 250, 250, 183],
#        [250, 250, 250, 250],
#        [100, 194, 138, 100]])

# %%
b = np.random.randint(1,10,(2,7))
c = np.random.randint(1,10,7)

# %%
b
# Out:
# array([[1, 5, 6, 1, 7, 4, 5],
#        [1, 3, 7, 3, 4, 6, 1]])

# %%
c
# Out:
# array([4, 7, 9, 5, 1, 4, 4])

# %%
b+c
# Out:
# array([[ 5, 12, 15,  6,  8,  8,  9],
#        [ 5, 10, 16,  8,  5, 10,  5]])

# %%
d = np.random.randint(1,10,(9,4))
e = np.random.randint(1,10,9)

# %% [markdown]
# ### d

# %%
e
# Out:
# array([7, 5, 4, 3, 3, 5, 2, 3, 4])

# %%
d+e
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 d+e
#
# ValueError: operands could not be broadcast together with shapes (9,4) (9,)

# %%
# Introdution to Pandas

# %%
# Data Science
# Data: Explore | EDA: Expolatroy Data Analysis

# %%
# Data Explore:- Report (insight)

# Report >>> Data Scientist

# %%
import pandas as pd 
pd.__version__
# Out:
# '1.4.2'

# %%
import random 

product = ['Chair','Tables','Laptop','Mobile','Charger']
all_date = pd.date_range('01-01-2025', '23-07-2025')
Region = ['east','west','north','South']

data = {'Order_ID':range(1,1001),
        'Date':random.choices(all_date,k= 1000),
        'Region Name': random.choices(Region,k = 1000),
       'Product Name': random.choices(product,k = 1000),
       'Sales': np.random.randint(100,1000,1000),
       'Qty': np.random.randint(1,10,1000),
       'Profit': np.random.randint(-10000,10000,1000)}


table = pd.DataFrame(data)
table
# Out:
#      Order_ID       Date Region Name Product Name  Sales  Qty  Profit
# 0           1 2025-04-28       South       Mobile    508    4    5074
# 1           2 2025-02-20       north       Laptop    715    5   -3544
# 2           3 2025-03-04        east      Charger    347    7    4745
# 3           4 2025-04-03       north        Chair    896    1   -2538
# 4           5 2025-04-11        east       Laptop    561    2    8890
# ..        ...        ...         ...          ...    ...  ...     ...
# 995       996 2025-03-08       north       Mobile    469    1    2186
# 996       997 2025-06-29       South        Chair    666    7    9671
# 997       998 2025-02-02        east      Charger    100    1     779
# 998       999 2025-04-05        east      Charger    279    7    5899
# 999      1000 2025-07-20       north        Chair    843    8    3607
#
# [1000 rows x 7 columns]

# %%
all_date = pd.date_range('01-01-2025', '23-07-2025')
# Out:
# D:\New folder\lib\site-packages\IPython\core\interactiveshell.py:3369: UserWarning: Parsing '23-07-2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
table.head(10)
# Out:
#    Order_ID       Date Region Name Product Name  Sales  Qty  Profit
# 0         1 2025-04-28       South       Mobile    508    4    5074
# 1         2 2025-02-20       north       Laptop    715    5   -3544
# 2         3 2025-03-04        east      Charger    347    7    4745
# 3         4 2025-04-03       north        Chair    896    1   -2538
# 4         5 2025-04-11        east       Laptop    561    2    8890
# 5         6 2025-03-15        east       Tables    534    6     157
# 6         7 2025-04-13        east       Mobile    610    8    5157
# 7         8 2025-06-23       north       Tables    302    5    6975
# 8         9 2025-05-09       South       Mobile    535    2   -4501
# 9        10 2025-07-22       South       Tables    613    4    9493

# %%
table.tail(10)
# Out:
#      Order_ID       Date Region Name Product Name  Sales  Qty  Profit
# 990       991 2025-02-15       north      Charger    161    5    9649
# 991       992 2025-01-12        west       Laptop    852    9    5477
# 992       993 2025-05-14        west       Tables    837    1    6399
# 993       994 2025-03-13        east       Mobile    951    3   -7126
# 994       995 2025-04-12       north      Charger    462    1   -7403
# 995       996 2025-03-08       north       Mobile    469    1    2186
# 996       997 2025-06-29       South        Chair    666    7    9671
# 997       998 2025-02-02        east      Charger    100    1     779
# 998       999 2025-04-05        east      Charger    279    7    5899
# 999      1000 2025-07-20       north        Chair    843    8    3607

# %%
 table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      1000 non-null   int64
#  1   Date          1000 non-null   datetime64[ns]
#  2   Region Name   1000 non-null   object
#  3   Product Name  1000 non-null   object
#  4   Sales         1000 non-null   int32
#  5   Qty           1000 non-null   int32
#  6   Profit        1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
# Columns Names

table.columns
# Out:
# Index(['Order_ID', 'Date', 'Region Name', 'Product Name', 'Sales', 'Qty',
#        'Profit'],
#       dtype='object')

# %%
# Index

table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# isna(): it will check nan value counts

table.isna()
# Out:
#      Order_ID   Date  Region Name  Product Name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]

# %%
table.isnull().value_counts()
# Out:
# Order_ID  Date   Region Name  Product Name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# dtype: int64

# %%
table.isna().value_counts()
# Out:
# Order_ID  Date   Region Name  Product Name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# dtype: int64
